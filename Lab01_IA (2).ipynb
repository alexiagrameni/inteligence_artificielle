# %% [markdown]
# # Intelligence Artificielle - Automne 2025 - Laboratoire 01
# # Introduction en Python 1ère partie

# %%
my_var = int(my_var)
result = my_str + ' ' + str(my_var)

# %%
noun = 'layer'
verb = 'has'
number = 128
punctuation = '.'

# %%
sentence = 'This {} {} {} neurons{}'.format(noun, verb, number, punctuation)
print(sentence)

# %%
A = []
B = [0, 2, 4, 6]
C = []
for x in B:
    C.append(x + 1)

# %%
B[2] = 0

# %%
diff_elems = B[1:3]

# %%
for k, v in scientists_dict.items():
    print(k, v)
print(scientists_dict.keys())
print(scientists_dict.values())

# %%
print(scientists_dict.get(3))
scientists_dict[3]

# %%
scientists_dict['new'] = 'Andrew Ng'

# %%
total_publications = sum([v for v in publications.values() if isinstance(v, int)])

# %%
my_str = 'awareness'
new_str = ''.join([c for i, c in enumerate(my_str) if i % 2 == 0])

# %%
n = 9
d = {x: 2*x**2 + 3*x for x in range(1, n+1)}
list1 = [v for v in d.values() if v % 3 == 0]
list2 = [v for v in d.values() if v % 2 == 0]
list3 = sorted(list(set(list1).intersection(set(list2))))
