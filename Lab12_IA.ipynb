# %% [markdown]
# # Intelligence artificielle - Automne 2025 - Laboratoire 12
#
# ## _Apprentissage non supervisé:   Hierarchical Clustering et K-Means_

# %% [markdown]
# ## Agglomerative Hierarchical Clustering
#
# Des lectures utiles peuvent être trouvées [ici](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html) et [ici](https://en.wikipedia.org/wiki/Hierarchical_clustering).
#
#
# ### Brève démonstration

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import matplotlib.pyplot as plt

# %%
# Values extracted from the official scikit-learn documentation (check the first link).
X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0]])

# %%
X
# Out:
# array([[1, 2],
#        [1, 4],
#        [1, 0],
#        [4, 2],
#        [4, 4],
#        [4, 0]])

# %%
# Visualise data
plt.scatter(X[:,0], X[:,1])

# %%
# Agglomerative Hierarchical Clustering model with no parameters
aggl_model_demo = AgglomerativeClustering().fit(X)

# %%
aggl_model_demo
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=2,
#                         pooling_func='deprecated')

# %%
# Cluster labels for each point
aggl_model_demo.labels_
# Out:
# array([1, 1, 1, 0, 0, 0], dtype=int64)

# %%
# Visualise data

plt.scatter(X[:,0], X[:,1])
plt.scatter(X[aggl_model_demo.labels_,0], X[aggl_model_demo.labels_,1], c='r')

# %% [markdown]
# ### Tâche 0
#
# Jouez avec `data.txt` et:
# * Plottez les données avant d'appliquer l'algorithme _Agglomerative Hierarchical Clustering_ (**TO DO1**);
# * **TO DO2** :
#     - Définissez une nouvelle variable _X_ pour stocker `data_txt`,
#     - Appliquez l'algorithme _Agglomerative Hierarchical Clustering_ et modifiez ses paramètres pour 15 clusters ;
#     - Notez vos observations pour différentes valeurs d'`affinity` (_"euclidien"_ ou _"manhattan"_) et de `linkage` (_"ward"_ ou _"complete"_) ;
# * Visualisez les groupes obtenus.
#
# _Note:_ A la fin de cette tâche, veuillez utiliser l'option `markdown` fournie dans le notebook pour vos observations.

# %%
# Load data for this exercise
data_txt = np.loadtxt('data.txt', usecols=(0, 1), skiprows=1)

# %%
data_txt
# Out:
# array([[665845., 557965.],
#        [597173., 575538.],
#        [618600., 551446.],
#        ...,
#        [650661., 861267.],
#        [599647., 858702.],
#        [684091., 842566.]])

# %%
# TO DO1
# Expected Output:

# %%
# TO DO2
X 

# Define model

# Use the fit_predict() function
y_predict

# Get the labels and use them in your plot
labels

# %%
# Expected plot for TO DO2

# %% [markdown]
# **TO DO3**: Utilisez le _Nearest Centroid_ [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.NearestCentroid.html) pour calculer les centroïdes de chaque cluster.

# %%
# TO DO3
# Expected Output:
print('Centroids:')
print(centroids)
# Out:
# Centroids:
# [[858523.47107438 549109.0137741 ]
#  [321607.60349854 161194.23323615]
#  [672400.67597765 861555.2849162 ]
#  [619663.6884273  398658.75074184]
#  [140019.83526012 558305.60115607]
#  [417799.69426752 787001.99363057]
#  [399223.625      404923.23579545]
#  [337858.94189602 562276.80428135]
#  [167727.3880597  348147.6       ]
#  [508441.62931034 176054.77873563]
#  [823717.6744186  733102.37209302]
#  [244654.8856305  847642.04105572]
#  [606060.5959596  574146.15824916]
#  [802138.44551282 319314.90384615]
#  [852675.82769231 157386.94461538]]

# %% [markdown]
# **TO DO4:** Itérez les étiquettes(labels) obtenues et visualisez chaque cluster avec son centroïde correspondant.

# %%
unique_labels = np.unique(labels)

for i in unique_labels:
    # TO DO4

# %%
# Expected Output:

# %% [markdown]
# ## K-Means
#
# Veuillez vous référer à ce [document](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) pour plus d'informations.

# %% [markdown]
# ### Tâche 1
#
# Jouez avec `data.txt` et:
# * **TO DO1**: Appliquez l'algorithme _K-Means Clustering_ et générez 15 clusters ;
# * **TO DO2**: Notez vos observations pour le paramètre `algorithm` (_"full"_ ou _"elkan"_);
# * **TO DO3**: Calculez les centroïdes pour chaque groupe;
# * **TO DO4**: visualisez chaque cluster avec son centroïde correspondant.
#
# _Note:_ A la fin de cette tâche, veuillez utiliser l'option `markdown` fournie dans le notebook pour vos observations.

# %%
# TO DO1

# %%
# TO DO2

# %%
# TO DO3

# %%
# Expected Output:
centroids
# Out:
# array([[320602.55      , 161521.85      ],
#        [858947.97134671, 546259.65902579],
#        [337264.76291793, 562123.37993921],
#        [417799.69426752, 787001.99363057],
#        [852058.45259939, 157685.52293578],
#        [507818.31339031, 175610.41595441],
#        [606380.41554054, 574534.59121622],
#        [139395.22898551, 558143.94202899],
#        [670929.06818182, 862765.73295454],
#        [244654.8856305 , 847642.04105572],
#        [801616.78164557, 321123.34177215],
#        [617926.67761194, 399415.94925373],
#        [398870.04843305, 404924.06552707],
#        [823421.2507837 , 731145.27272727],
#        [167856.14071856, 347812.71556886]])

# %%
unique_labels = np.unique(labels)

for i in unique_labels:
    # TO DO4

# %% [markdown]
# ### Tâche 2
#
# Essayez de modifier le nombre de clusters pour `data2.txt` et notez vos observations pour le modèle _Agglomerative Hierarchical Clustering_.
